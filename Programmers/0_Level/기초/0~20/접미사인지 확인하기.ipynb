# %%
my_string = "banana"
is_suffix = "ana"

# %%
answer = 0
zub_list= []

# %%
for i in range(len(my_string)):
        print(f'i ={i}')
        zub_list.append(my_string[-i:])
        print(zub_list)
# Out:
# i =0
# ['banana']
# i =1
# ['banana', 'a']
# i =2
# ['banana', 'a', 'na']
# i =3
# ['banana', 'a', 'na', 'ana']
# i =4
# ['banana', 'a', 'na', 'ana', 'nana']
# i =5
# ['banana', 'a', 'na', 'ana', 'nana', 'anana']

# %%
if is_suffix in zub_list:
        answer=1

# %%
print(answer)
# Out:
# 1
